# %% [markdown]
# <a href="https://colab.research.google.com/github/haneefkhan788412-cell/python-work/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
2*10
# Out:
# 20

# %%
2*34
# Out:
# 68

# %%
type(10)
# Out:
# int

# %%
type(10.0)
# Out:
# float

# %%
type('abc')
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
eno=10
ename="haneef"
esal=345.45
print("the give Employee number is",eno)
print("the given empolyee name is",ename)
print("the given empolyee salary is",esal)
# Out:
# the give Employee number is 10
# the given empolyee name is haneef
# the given empolyee salary is 345.45

# %%
a= int(input("Enter a value:"))
b=int(input("Enter b value:"))
print(type(a))
print(type(b))
print(a+b)
# Out:
# Enter a value:10
# Enter b value:20
# <class 'int'>
# <class 'int'>
# 30

# %%
eno=int(input("Enter Employee Number:"))
ename=mahak(input("Enter Employee Name:"))
esal=float(input("Enter Employee Salary"))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3891209505.py in <cell line: 0>()
# ----> 1 eno=int(input("Enter Employee Number:"))
#       2 ename=mahak(input("Enter Employee Name:"))
#       3 esal=float(input("Enter Employee Salary"))
#       4
#       5
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
#Write a Python Program To Enter Radius of Circle and Find the Area ?
radius=int(input("Enter the Radius of Circle:"))
pi=3.14
area=pi*radius*radius
print("The Area of Circle is",area)
# Out:
# Enter the Radius of Circle:2
# The Area of Circle is 12.56

# %%
#Write a python Program Find the Area and Circumference of Rectangle ?
length=int(input("Enter the lenghth of Rectangle:"))
breadth=int(input("Enter the breadth of Rectangle:"))
Area=length*breadth
Circumference=2*(length+breadth)
print("The Area of Rectangle is",area)
print("The Circumference of Rectangle is",Circumference)
# Out:
# Enter the lenghth of Rectangle:4
# Enter the breadth of Rectangle:6
# The Area of Rectangle is 12.56
# The Circumference of Rectangle is 20

# %%
#Write a python program to check the person whether eligible for voting or not ?
age=int(input())
if age>=18:
  print("ELigible for Voting")
else:
  print("Not Eligible for Voting")
  Print
# Out:
# 18
# ELigible for Voting

# %%
#write a python program to check the given number is positive or negative or zero?
num=int(input())
if num>0:
  print("the given nuber is positive")
elif num<0:
  print("the given number is negative")
else:
  print("the given number is zero")
# Out:
# 5
# the given nuber is positive
